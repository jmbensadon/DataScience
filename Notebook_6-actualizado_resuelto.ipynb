# %% [markdown]
# ### 🤖 Guía de Asistencia con IA: IA como Copiloto de Programación
#
# En esta notebook, utilizaremos la Inteligencia Artificial como copiloto de aprendizaje. Aquí tienes algunas sugerencias de cómo interactuar con un asistente de IA (como Gemini o ChatGPT):
#
# - **Explicación de código**: Si encuentras una función o línea que no comprendes, pregúntale a la IA: *'Explica qué hace esta función línea por línea en Python: [pega tu código]'*.
# - **Corrección de errores**: Si tienes un error al ejecutar, copia el error completo y pregúntale: *'¿Por qué este código genera este error y cómo lo soluciono? [pega tu código y error]'*.
# - **Optimización**: Pregunta: *'¿Cómo puedo escribir este código de forma más eficiente y limpia?'*.

# %% [markdown]
# # Programa Ingenias+ en Data Science
#
# Como dijimos en clases anteriores, Python tiene implementadas muchas librerias para poder trabajar con datos. En la clase de hoy trabajaremos con una de ellas: `Pandas`.
#
# Antes de comenzar, vamos a hablar un poco de esta libreria.
#
# **Pandas** es una libreria que es una extensión de NumPy. Basicamente al utilizar `pandas`, utilizo `numpy` por debajo. Esta orientada a la manipulación y análisis de datos debido a que ofrece estructuras de datos y operaciones para manipular tablas numéricas y series temporales.
#
# La estructura principal de `pandas` es el `DataFrame` que es muy similar a una tabla. Así también, contiene otra estrucutra denominada `Serie`.
#
# Al ser de código abierto, `pandas` posee una documentación muy amplia que es **SIEMPRE RECOMENDABLE** consultar.
#
# - [Documentacion Pandas](https://pandas.pydata.org/pandas-docs/stable/)

# %% [markdown]
# ## Clase 5: Pandas

# %% [markdown]
# Pandas es una gran ayuda para manejar nuestros dataset. En la clase de hoy, veremos algunos conceptos basicos de pandas y como leer datasets.

# %%
#importa numpy
import numpy as np
#importa pandas
import pandas as pd

# %%
zanahoria = pd.Series(data = [1,2,3, 4, 6.7],
          index=['primero', 'segundo' ,'tercero', 'cuarto', 'quinto'])

# %%
type(zanahoria)
# Out:
# pandas.Series

# %%
zanahoria
# Out:
# primero    1.0
# segundo    2.0
# tercero    3.0
# cuarto     4.0
# quinto     6.7
# dtype: float64

# %%
zanahoria['tercero']
# Out:
# np.float64(3.0)

# %%
zanahoria
# Out:
# primero    1.0
# segundo    2.0
# tercero    3.0
# cuarto     4.0
# quinto     6.7
# dtype: float64

# %%
# Para si un objeto tiene una columna, lo que hacemos es guardar
# en una variable
espejo = pd.DataFrame(data = [1,"rosa",3, 4, 6.7],
          index=['primero', 'segundo' ,'tercero','cuarto',  'quinto'])
# Cuando creamos una variable tipo dataframe,
# debo tener la misma cantidad de datos que de indices

# %%
espejo.index
# Out:
# Index(['primero', 'segundo', 'tercero', 'cuarto', 'quinto'], dtype='str')

# %%
espejo.columns # metodo columna stop=1 una sola columna
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %% [markdown]
# Pandas nos facilita con varias funciones para leer archivos. Entre ellas podemos encontrar:
#
# - `.read_csv()`: lee archivos `csv` como DataFrame
# - `.read_json()`: lee archivos `json` como DataFrame
# - `.read_excel()`: leer archivos `excel` como DataFrame
#
# Para conocer más funciones que ayuden a leer archivos, consulta [acá](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html)

# %% [markdown]
# Nosotras vamos a usar [`.read_csv()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html).

# %% [markdown]
# Los archivos `csv` son un tipo de documento en formato abierto sencillo para representar datos en forma de tabla, en las que las columnas se separan por comas (o punto y coma) y las filas por saltos de línea. Es uno de los formatos más utilizados en Data Science.

# %% [markdown]
# La sintaxis para poder leer un archivo csv es:
#
# `df = pd.read_csv('nombredelarchivo.csv', delimiter=',')`
#
# Aunque muchas veces se omite el `delimiter` si el archivo esta separado por comas.

# %% [markdown]
# Vamos a trabajar con el archivo `StudentsPerformance.csv`. Es usual descargar el archivo `csv` en la misma carpeta en la que trabajas con el jupyter notebook. De esta manera, no tendras que especificar el path a tu archivo.

# %% [markdown]
# 1) Lee el archivo csv `StudentsPerformace` usando `pandas`. Guardalo en una variable llamada `students`.

# %%
# Leemos el archivo StudentsPerformance.csv de forma local
# (se reemplaza el montaje de Google Drive porque estamos trabajando en un entorno local, no en Colab)
students = pd.read_csv('StudentsPerformance.csv')

# Guardamos tambien una referencia como 'df' porque el resto de la notebook usa ese nombre
df = students
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # Nueva sección

# %%
# @title parental level of education

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('parental level of education').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='str')

# %% [markdown]
# 2) ¿Que tipo de estructura de datos contiene la variable `students`? _Hint_: Usa `type`

# %%
type(df)
# Out:
# pandas.DataFrame

# %% [markdown]
# 3) ¿Cuantas filas y columnas tiene `students`? Para contestar esta pregunta, pandas tiene la funcion `.shape()`. Su sintaxis es la siguiente: `df.shape()` (`df` debe ser reemplazado por el nombre de tu `DataFrame`).
#
#
# De ahora en más cuando nos refiramos a un tipo de sintaxis donde debe colocarse `nombre_del_data_frame.funcion()`, la mencionaremos como `.funcion()`.
#
# ¿Que devuelve esta funcion? ¿Cual crees que corresponde a las filas y cual a las columnas?

# %% [markdown]
# **Numero de filas**: 1000

# %% [markdown]
# **Numero de columnas**: 8

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# 3) ¿Cual es el nombre de las columnas contenidas en `students`? Para esto, pandas tiene el atributo `.columns`.

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='str')

# %% [markdown]
# 4) Inspecciona las primeras 10 filas de `students` usando la función `.head()`. Dentro de esta función podemos colocar un numero. Este numero nos dira cuantas filas queremos observar.

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# 5) Ahora inspecciona las 10 ultimas usando `.tail()`. También podemos indicar el número de filas que queremos observar.

# %%
df.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# 991               completed          65             82             78
# 992                    none          55             76             76
# 993                    none          62             72             74
# 994                    none          63             63             62
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %% [markdown]
# 6) ¿Que tipos de datos contiene cada una de las columnas de `students`? Para esto, utiliza el atributo `.dtypes`.

# %%
df.dtypes
# Out:
# gender                           str
# race/ethnicity                   str
# parental level of education      str
# lunch                            str
# test preparation course          str
# math score                     int64
# reading score                  int64
# writing score                  int64
# dtype: object

# %% [markdown]
# 7) ¿Como accedemos a una fila o a una columa de un DataFrame?

# %% [markdown]
# Una de las maneras de acceder a una columna es especificando el nombre de la misma. Por ejemplo, `df['nombre_columna']`.

# %% [markdown]
# - Accede a la columna `gender` de `students`.

# %%
df['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: str

# %%
df.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: str

# %% [markdown]
# - Accede ahora a la columna `lunch`.

# %%
df['lunch']
# Out:
# 0          standard
# 1          standard
# 2          standard
# 3      free/reduced
# 4          standard
#            ...
# 995        standard
# 996    free/reduced
# 997    free/reduced
# 998        standard
# 999    free/reduced
# Name: lunch, Length: 1000, dtype: str

# %%
df.lunch
# Out:
# 0          standard
# 1          standard
# 2          standard
# 3      free/reduced
# 4          standard
#            ...
# 995        standard
# 996    free/reduced
# 997    free/reduced
# 998        standard
# 999    free/reduced
# Name: lunch, Length: 1000, dtype: str

# %% [markdown]
# Otra manera de acceder es usando dos funciones `.loc[]` y `.iloc[]`.

# %% [markdown]
# - `iloc[1:m, 1:n]`: Se usa para seleccionar filas basadas en su posición de 1 a m filas y de 1 a n columnas.

# %%
#seleccionar las dos primeras filas
df.iloc[:2, :3]
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college

# %%
#o tambien se usa
df.iloc[:5,]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.iloc[2,-2]
# Out:
# np.int64(95)

# %%
#Selecciona los datos entre la decima y vigesima fila.
df.iloc[10:21]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# 13    male        group A                some college      standard
# 14  female        group A             master's degree      standard
# 15  female        group C            some high school      standard
# 16    male        group C                 high school      standard
# 17  female        group B            some high school  free/reduced
# 18    male        group C             master's degree  free/reduced
# 19  female        group C          associate's degree  free/reduced
# 20    male        group D                 high school      standard
#
#    test preparation course  math score  reading score  writing score
# 10                    none          58             54             52
# 11                    none          40             52             43
# 12                    none          65             81             73
# 13               completed          78             72             70
# 14                    none          50             53             58
# 15                    none          69             75             78
# 16                    none          88             89             86
# 17                    none          18             32             28
# 18               completed          46             42             46
# 19                    none          54             58             61
# 20                    none          66             69             63

# %%
#Selecciona las dos primeras columnas
df.iloc[:, :2]
# Out:
#      gender race/ethnicity
# 0    female        group B
# 1    female        group C
# 2    female        group B
# 3      male        group A
# 4      male        group C
# ..      ...            ...
# 995  female        group E
# 996    male        group C
# 997  female        group C
# 998  female        group D
# 999  female        group D
#
# [1000 rows x 2 columns]

# %% [markdown]
# - `.loc[[nombre_fila], [nombre_columna]]`. Se usa para seleccionar filas o columnas basadas en su nombre

# %%
#Selecciona la fila por nombre 1, o sea con indice igual a 1
df.loc[1]
# Out:
# gender                               female
# race/ethnicity                      group C
# parental level of education    some college
# lunch                              standard
# test preparation course           completed
# math score                               69
# reading score                            90
# writing score                            88
# Name: 1, dtype: object

# %%
#Corre el codigo y observa que devuelve
df.loc[[1,20,3,4,5],['gender','lunch']]
# Out:
#     gender         lunch
# 1   female      standard
# 20    male      standard
# 3     male  free/reduced
# 4     male      standard
# 5   female      standard

# %%
#Selecciona las filas con indices 3, 10, 30, 43, 43 y columnas reading score y writing score
df.loc[[3, 10, 30, 43, 43], ['reading score', 'writing score']]
# Out:
#     reading score  writing score
# 3              57             44
# 10             54             52
# 30             74             74
# 43             65             66
# 43             65             66

# %%
df2 = pd.DataFrame(data = ['perro', 'gato', 'flor'], index = ['str1', 'str2', 'st32'], columns=['titulo'])

# %%
df2
# Out:
#      titulo
# str1  perro
# str2   gato
# st32   flor

# %%
df2.loc['str2']
# Out:
# titulo    gato
# Name: str2, dtype: str

# %%
df2.iloc[1]
# Out:
# titulo    gato
# Name: str2, dtype: str

# %% [markdown]
# 8) A veces queremos seleccionar filas que cumplan con ciertas condiciones, donde el valor de una columna en esa fila sea igual, mayor o menor que un valor.
#
# Para esto tenemos que usar una sintaxis especial. Vamos a construirla de a poco. Imaginemos que tenemos un DataFrame `df` con las columnas `col1`, `col2` y `col3`. Queremos seleccionar solo aquellas filas donde `col1` sea mayor a 10.
#
# Para eso diremos que queremos
#
# df['col1'] > 10 (La columna col1 debe ser mayor a 10).
# Ahora si corremos este codigo, veremos que devuelve valores booleanos. O sea devolvera False para aquellos valores que sean menores o iguales a 10 y True para los que sean mayores a 10.
#
# O sea que tenemos que agregar algo mas para poder seleccionar las columnas. Esta lista de valores booleanos se llama mascara booleana.
#
# ¿Que significa? Que si yo le paso estos valores a pandas, pandas interpretara que debe conservar aquellos valores donde tiene True y descartar donde tiene False.
#
# Por eso, para filtrar filas en base a estas condiciones escribimos:
#
# df[df['col1] > 10].
#
# Esto significa primero fijate en que filas de `df`, la columna `col1` es mayor a 10. Luego, selecciona solo aquellas filas donde esta condicion sea `True`.

# %%
ejemplo = pd.DataFrame(data = [100,2,3, 4, 15,34],
          index=[1,2,3,4,5,6], columns=["col1"])

# %%
ejemplo
# Out:
#    col1
# 1   100
# 2     2
# 3     3
# 4     4
# 5    15
# 6    34

# %%
ejemplo['col1']>10
# Out:
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# Name: col1, dtype: bool

# %%
ejemplo[ejemplo['col1']>10]
# Out:
#    col1
# 1   100
# 5    15
# 6    34

# %%
#Selecciona solo las filas donde math score sea mayor a 70
df[df['math score']>7.0]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [999 rows x 8 columns]

# %%
#Selecciona solo las filas donde reading score sea menor a 60

df[df['reading score']<60]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 14   female        group A             master's degree      standard
# ..      ...            ...                         ...           ...
# 980  female        group B                 high school  free/reduced
# 985    male        group A                 high school      standard
# 986  female        group C          associate's degree      standard
# 988  female        group A            some high school  free/reduced
# 996    male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# 7                      none          40             43             39
# 10                     none          58             54             52
# 11                     none          40             52             43
# 14                     none          50             53             58
# ..                      ...         ...            ...            ...
# 980                    none           8             24             23
# 985                    none          57             51             54
# 986                    none          40             59             51
# 988                    none          44             45             45
# 996                    none          62             55             55
#
# [254 rows x 8 columns]

# %%
#Selecciona solo las filas donde gender sea igual a female
df[df['gender']=='female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 5                      none          71             83             78
# 6                 completed          88             95             92
# ..                      ...         ...            ...            ...
# 993                    none          62             72             74
# 995               completed          88             99             95
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [518 rows x 8 columns]

# %%
#Selecciona solo aquellas filas donde lunch sea distinto a standardisnull

df[df['lunch']!='standard']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# 7                      none          40             43             39
# 8                 completed          64             64             67
# 9                      none          38             60             50
# 17                     none          18             32             28
# ..                      ...         ...            ...            ...
# 992                    none          55             76             76
# 993                    none          62             72             74
# 996                    none          62             55             55
# 997               completed          59             71             65
# 999                    none          77             86             86
#
# [355 rows x 8 columns]

# %%
#Muestra los valores de writing score para aquellos estudiantes que tengan reading score mayor a math score

df[df['reading score']>df['math score']]['writing score']
# Out:
# 1      88
# 2      93
# 3      44
# 4      75
# 5      78
#        ..
# 993    74
# 995    95
# 997    65
# 998    77
# 999    86
# Name: writing score, Length: 604, dtype: int64

# %%
df[(df['reading score']>70) & (df['writing score']>70)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 4                      none          76             78             75
# 5                      none          71             83             78
# ..                      ...         ...            ...            ...
# 992                    none          55             76             76
# 993                    none          62             72             74
# 995               completed          88             99             95
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [419 rows x 8 columns]

# %% [markdown]
# 9) Los valores faltantes son un problema muy grande a la hora de visualizar y limpiar datos así como también a la hora de entrenar un modelo. Uno de los pasos obligados de cualquier exploración de datos es evaluar la presencia de estos valores.
#
# Como manejar estos datos faltantes es un gran desafio. La mayoría de las veces no queremos eliminar esos valores porque significaría perder información valiosa en otros features. En la proxima clase veremos como podemos manejarlos.
#
# Los valores faltantes estan codificados normalemente como `NaN`. Esto no es un string, sino que es un valor especial de `NumPy` que es tratado como un flotante.
#
# Para chequear si tenemos valores faltantes podemos usar la función `.isnull()`. Esto nos devuelve una nueva DataFrame en la cual tendremos el valor False si no es faltante y True si ese valor es faltante.

# %%
#Usa .isnull() para ver que ocurre
new_df = pd.DataFrame({
    'nombre': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve', 'Frank', 'Grace', 'Henry', 'Iris', 'Jack'],
    'edad': [25, 30, np.nan, 28, 35, np.nan, 22, 29, 31, 26],
    'ciudad': ['Madrid', np.nan, 'Barcelona', 'Valencia', 'Sevilla', 'Bilbao', np.nan, 'Málaga', 'Zaragoza', 'Palma'],
    'salario': [45000, 52000, 48000, np.nan, 61000, 55000, 50000, np.nan, 59000, 47000],
    'experiencia': [2, np.nan, 5, 3, 8, np.nan, 1, 4, 6, 2]
})
new_df

new_df.isnull()
# Out:
#    nombre   edad  ciudad  salario  experiencia
# 0   False  False   False    False        False
# 1   False  False    True    False         True
# 2   False   True   False    False        False
# 3   False  False   False     True        False
# 4   False  False   False    False        False
# 5   False   True   False    False         True
# 6   False  False    True    False        False
# 7   False  False   False     True        False
# 8   False  False   False    False        False
# 9   False  False   False    False        False

# %% [markdown]
# Podemos sin embargo combinar esta función con otras para poder obtener el numero total de datos faltantes. Por ejemplo, podemos usar `.isnull().sum()`.

# %%
#Prueba usar .isnull().sum() sobre tu dataframe para ver que devuelve
new_df.isnull().sum()
# Out:
# nombre         0
# edad           2
# ciudad         2
# salario        2
# experiencia    2
# dtype: int64

# %% [markdown]
# ```
# # Esto tiene formato de código
# ```
#
# ¿Hay valores faltantes en alguna de las columnas de `students`? **No.** Al correr `df.isnull().sum()` se observa que todas las columnas tienen 0 valores nulos (se puede confirmar con `df.isnull().sum().sum()`, que da 0). Esto se debe a que el dataset `StudentsPerformance.csv` viene completo, sin datos faltantes.

# %% [markdown]
# 10) Si la cantidad de valores faltantes es poca, podemos entonces deshacernos de ellas. Para esto pandas ofrece la función [`.dropna()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html). Esta función hara que se eliminen las filas donde hay valores faltantes. Si no le pasamos ningun parametro extra, eliminara todas las filas con valores faltantes. Sin embargo, podes chequear en la documentación como eliminar solo algunas de las filas.

# %%
#Elimina todas las filas que tengan valores faltantes. No te olvides de poner inplace=True dentro de la función.
df.dropna(inplace=True)
new_df.dropna(inplace=True)
new_df
# Out:
#   nombre  edad    ciudad  salario  experiencia
# 0  Alice  25.0    Madrid  45000.0          2.0
# 4    Eve  35.0   Sevilla  61000.0          8.0
# 8   Iris  31.0  Zaragoza  59000.0          6.0
# 9   Jack  26.0     Palma  47000.0          2.0

# %% [markdown]
# 12) Una manera de ver facilmente algunos detalles estadisticos de cada columna de un DataFrame es usando la fución `.describe()`.

# %%
#Usa la funcion .describe() sobre students y describe que informacion estadistica proporciona
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# Tambien es posible visualizar, por ejemplo, el promedio de una columna. Para esto pandas usa la función de numpy, pero provee la misma sintaxis que las demás funciones. Por ejemplo, si queremos calcular el promedio de la columna `col1` del DataFrame `df` usamos `df['col1'].mean()`.

# %%
#Calcula el promedio de la columna math score de students
df['math score'].mean()
# Out:
# np.float64(66.089)

# %% [markdown]
# También podemos usar funciones como `.min()`, `.max()`, `.median()`, `.std()`.

# %%
#Calcula el minimo y maximo valor, la mediana y el desvio estandard en la columna math score de students
df['math score'].min()
df['math score'].max()
df['math score'].median()
df['math score'].std()
# Out:
# np.float64(15.16308009600945)

# %% [markdown]
# 13) Ahora repite el mismo analisis estadistico (minimo, maximo, mediana y desvio estandar) pero para las columnas `reading score` y `writing score`. Esto nos permite comparar el comportamiento de las tres materias.

# %%
#Estadisticas descriptivas para reading score
print('Minimo reading score:', df['reading score'].min())
print('Maximo reading score:', df['reading score'].max())
print('Mediana reading score:', df['reading score'].median())
print('Desvio estandar reading score:', df['reading score'].std())
# Out:
# Minimo reading score: 17
# Maximo reading score: 100
# Mediana reading score: 70.0
# Desvio estandar reading score: 14.600191937252216

# %%
#Estadisticas descriptivas para writing score
print('Minimo writing score:', df['writing score'].min())
print('Maximo writing score:', df['writing score'].max())
print('Mediana writing score:', df['writing score'].median())
print('Desvio estandar writing score:', df['writing score'].std())
# Out:
# Minimo writing score: 10
# Maximo writing score: 100
# Mediana writing score: 69.0
# Desvio estandar writing score: 15.19565701086965

# %%
# Comparamos el promedio de las tres materias en un mismo lugar
df[['math score', 'reading score', 'writing score']].mean()
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %% [markdown]
# 14) [Investiga](https://pandas.pydata.org/pandas-docs/stable/index.html) y trata de aplicar las siguientes funciones de `pandas`:

# %% [markdown]
# ```
#
# - `.index`

# %%
new_df = pd.DataFrame({
    'nombre': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve', 'Frank', 'Grace', 'Henry', 'Iris', 'Jack'],
    'edad': [25, 30, np.nan, 28, 35, np.nan, 22, 29, 31, 26],
    'ciudad': ['Madrid', np.nan, 'Barcelona', 'Valencia', 'Sevilla', 'Bilbao', np.nan, 'Málaga', 'Zaragoza', 'Palma'],
    'salario': [45000, 52000, 48000, np.nan, 61000, 55000, 50000, np.nan, 59000, 47000],
    'experiencia': [2, np.nan, 5, 3, 8, np.nan, 1, 4, 6, 2]
})
new_df
# Out:
#     nombre  edad     ciudad  salario  experiencia
# 0    Alice  25.0     Madrid  45000.0          2.0
# 1      Bob  30.0        NaN  52000.0          NaN
# 2  Charlie   NaN  Barcelona  48000.0          5.0
# 3    Diana  28.0   Valencia      NaN          3.0
# 4      Eve  35.0    Sevilla  61000.0          8.0
# 5    Frank   NaN     Bilbao  55000.0          NaN
# 6    Grace  22.0        NaN  50000.0          1.0
# 7    Henry  29.0     Málaga      NaN          4.0
# 8     Iris  31.0   Zaragoza  59000.0          6.0
# 9     Jack  26.0      Palma  47000.0          2.0

# %%
new_df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %% [markdown]
# - `.drop()`

# %% [markdown]
# ```
# # Esto tiene formato de código
# ```

# %%
new_df.drop(columns=['nombre'], inplace=True)
new_df
# Out:
#    edad     ciudad  salario  experiencia
# 0  25.0     Madrid  45000.0          2.0
# 1  30.0        NaN  52000.0          NaN
# 2   NaN  Barcelona  48000.0          5.0
# 3  28.0   Valencia      NaN          3.0
# 4  35.0    Sevilla  61000.0          8.0
# 5   NaN     Bilbao  55000.0          NaN
# 6  22.0        NaN  50000.0          1.0
# 7  29.0     Málaga      NaN          4.0
# 8  31.0   Zaragoza  59000.0          6.0
# 9  26.0      Palma  47000.0          2.0

# %% [markdown]
# - `.groupby()`

# %%
df.groupby('gender').mean(numeric_only=True)
# Out:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
# Tambien podemos usar .groupby() con mas de una columna y con distintas funciones de agregacion
df.groupby(['gender', 'test preparation course'])[['math score', 'reading score', 'writing score']].mean()
# Out:
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                 67.195652      77.375000      78.793478
#        none                      61.670659      69.982036      68.982036
# male   completed                 72.339080      70.212644      69.793103
#        none                      66.688312      62.795455      59.649351

# %% [markdown]
# - `.fillna()`

# %%
new_df.fillna(0)
# Out:
#    edad     ciudad  salario  experiencia
# 0  25.0     Madrid  45000.0          2.0
# 1  30.0          0  52000.0          0.0
# 2   0.0  Barcelona  48000.0          5.0
# 3  28.0   Valencia      0.0          3.0
# 4  35.0    Sevilla  61000.0          8.0
# 5   0.0     Bilbao  55000.0          0.0
# 6  22.0          0  50000.0          1.0
# 7  29.0     Málaga      0.0          4.0
# 8  31.0   Zaragoza  59000.0          6.0
# 9  26.0      Palma  47000.0          2.0

# %% [markdown]
# - `.rename()`

# %%
new_df.rename(columns={'ciudad':'lugar'}, inplace=True)

# %% [markdown]
# - `.astype()`

# %%
new_df.astype({'edad':'float'})
# Out:
#    edad      lugar  salario  experiencia
# 0  25.0     Madrid  45000.0          2.0
# 1  30.0        NaN  52000.0          NaN
# 2   NaN  Barcelona  48000.0          5.0
# 3  28.0   Valencia      NaN          3.0
# 4  35.0    Sevilla  61000.0          8.0
# 5   NaN     Bilbao  55000.0          NaN
# 6  22.0        NaN  50000.0          1.0
# 7  29.0     Málaga      NaN          4.0
# 8  31.0   Zaragoza  59000.0          6.0
# 9  26.0      Palma  47000.0          2.0

# %% [markdown]
# - `.unique()`

# %%
# Using .unique() on the 'lugar' column (which was previously 'ciudad') to see unique city names
new_df['lugar'].unique()
# Out:
# <StringArray>
# [   'Madrid',         nan, 'Barcelona',  'Valencia',   'Sevilla',    'Bilbao',
#     'Málaga',  'Zaragoza',     'Palma']
# Length: 9, dtype: str

# %% [markdown]
# - `.value_counts()`

# %%
df['test preparation course'].value_counts()
# Out:
# test preparation course
# none         642
# completed    358
# Name: count, dtype: int64

# %% [markdown]
# - `.count()`

# %% [markdown]
# ### `.count()`
#
# La función `.count()` se usa para obtener el número de valores no nulos en cada columna de un DataFrame o en una Serie. Es útil para verificar cuántas entradas válidas tienes en cada característica de tus datos.

# %%
# Usando .count() en new_df para ver el número de valores no nulos en cada columna
print("Conteo de valores no nulos en new_df:\n", new_df.count())
# Out:
# Conteo de valores no nulos en new_df:
#  edad           8
# lugar          8
# salario        8
# experiencia    8
# dtype: int64

# %% [markdown]
# - `.reset_index()`

# %% [markdown]
# ### `.reset_index()`
#
# La función `.reset_index()` se utiliza para restablecer el índice de un DataFrame o Serie. Mueve el índice actual a una columna regular (o lo descarta si `drop=True`) y establece un nuevo índice numérico predeterminado (de 0 a N-1). Es muy útil después de operaciones como `groupby()` que pueden generar un MultiIndex o un índice no secuencial.

# %%
# Primero, creamos un DataFrame de ejemplo con un índice personalizado para demostrar .reset_index()
example_df = pd.DataFrame({'value': [10, 20, 30]}, index=['A', 'B', 'C'])
print("DataFrame original:\n", example_df)

# Usamos .reset_index() para mover el índice 'A', 'B', 'C' a una columna
reset_df = example_df.reset_index()
print("\nDataFrame después de .reset_index():\n", reset_df)

# También podemos usar drop=True si no queremos que el índice anterior se convierta en una columna
reset_df_dropped = example_df.reset_index(drop=True)
print("\nDataFrame después de .reset_index(drop=True):\n", reset_df_dropped)
# Out:
# DataFrame original:
#     value
# A     10
# B     20
# C     30
#
# DataFrame después de .reset_index():
#    index  value
# 0     A     10
# 1     B     20
# 2     C     30
#
# DataFrame después de .reset_index(drop=True):
#     value
# 0     10
# 1     20
# 2     30
